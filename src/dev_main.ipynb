# %%
from main import run

run()
# Out:
# +-------+---+
# |   name|age|
# +-------+---+
# |  Alice| 34|
# |    Bob| 45|
# |Charlie| 29|
# +-------+---+
#
# root
#  |-- name: string (nullable = true)
#  |-- age: long (nullable = true)
